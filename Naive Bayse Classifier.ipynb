# %% [markdown]
# # Naive Bayse Classifier

# %% [markdown]
# ### Dataset 1

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from adspy_shared_utilities import plot_class_regions_for_classifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

X_C2, y_C2 = make_classification(n_samples=100, n_features=2, n_redundant=0,
                                n_informative=2, n_clusters_per_class=1, flip_y=0.1, class_sep=0.5,
                                random_state = 0)
X_train, X_test, y_train, y_test = train_test_split(X_C2, y_C2, random_state = 0)
clf_NBC = GaussianNB().fit(X_train, y_train)
plot_class_regions_for_classifier(clf_NBC, X_train, y_train, X_test, y_test, 
                                  'Gaussian Naive Bayse Classifier: Dataset 1')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ### Dataset 2

# %%
from sklearn.datasets import make_blobs
X_D2, y_D2 = make_blobs(n_samples=100, n_features=2, centers=8, cluster_std=1.3, random_state = 4)
y_D2 = y_D2 % 2 # To make 2 class 0 and 1
X_train, X_test, y_train, y_test = train_test_split(X_D2, y_D2, random_state =0)
clf_NBC2 = GaussianNB().fit(X_train, y_train)
plot_class_regions_for_classifier(clf_NBC2, X_train, y_train, X_test, y_test, 
                                  'Gaussian Naive Bayse Classifier: Dataset2')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ### Application to Real world Dataset

# %%
from sklearn.metrics import recall_score
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
(X_cancer, y_cancer) = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X_cancer, y_cancer, random_state = 0)

clf_NBC3 = GaussianNB().fit(X_train, y_train)
#plot_class_regions_for_classifier(clf_NBC3, X_train, y_train, X_test, y_test, 
 #                                 'Gaussian Naive Byse Classifier: Cancer data')
print('Accuracy score on train set: {:.3f}'.format(clf_NBC3.score(X_train, y_train)))
print('Accuracy score on test set: {:.3f}'.format(clf_NBC3.score(X_test, y_test)))
# Out:
# Accuracy score on train set: 0.951
# Accuracy score on test set: 0.937
